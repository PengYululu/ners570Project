# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = '/Users/qplazmfree/Documents/570/project/build/run/00018000.dat'

# Read the file
with open(filename, 'r') as file:
    # Read the first line to get ni and nj
    ni, nj = map(int, file.readline().split())
    
    # Initialize arrays to store primitive variables
    var1 = np.zeros((ni, nj))
    var2 = np.zeros((ni, nj))
    var3 = np.zeros((ni, nj))
    var4 = np.zeros((ni, nj))
    var5 = np.zeros((ni, nj))
    
    # Read the rest of the file line by line
    for i in range(ni):
        for j in range(nj):
            data = list(map(float, file.readline().split()))
            # x[i, j] = data[0]
            var1[i, j] = data[0]
            var2[i, j] = data[1]
            var3[i, j] = data[2]
            var4[i, j] = data[3]
            var5[i, j] = data[4]

def plot_map(variable, title):
    plt.imshow(variable, origin='lower', cmap='viridis')
    plt.colorbar()
    plt.title(title)
    plt.xlabel('j')
    plt.ylabel('i')
    plt.show()
plot_map(z, 'Z')
plot_map(var1, 'Variable 1')
plot_map(var2, 'Variable 2')
plot_map(var3, 'Variable 3')
plot_map(var4, 'Variable 4')
plot_map(var5, 'Variable 5')
